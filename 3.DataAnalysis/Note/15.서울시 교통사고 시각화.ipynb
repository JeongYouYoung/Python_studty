# %%
# 서울시 교통사고 시각화

# %%
import pandas as pd

# %%
traffic_Seoul = pd.read_csv("../Data/newSeoul_2005_2019.csv")
traffic_Seoul.head()
# Out:
#      년도  월 자치구명  발생건수  사망자수  부상자수
# 0  2005  1  종로구    93     2   138
# 1  2005  2  종로구    84     3   125
# 2  2005  3  종로구   117     0   142
# 3  2005  4  종로구   138     2   212
# 4  2005  5  종로구   145     2   207

# %%
# 2019년 데이터만 추출하기
# traffic_Seoul.info() -> 년도 int64
traffic_Seoul_2019 = traffic_Seoul[traffic_Seoul['년도'] == 2019]
# traffic_Seoul_2019['년도'].unique()

# index 값 0부터 시작하게 바꾸기
traffic_Seoul_2019.reset_index(drop=True, inplace=True)
traffic_Seoul_2019.head()
# Out:
#      년도  월 자치구명  발생건수  사망자수  부상자수
# 0  2019  1  종로구    87     1   125
# 1  2019  2  종로구    66     1    84
# 2  2019  3  종로구    87     2   122
# 3  2019  4  종로구    85     0   131
# 4  2019  5  종로구   112     1   158

# %%
# 자치구별, 발생건수, 사망자수, 부상자수, 집계하기
traffic_analysis = pd.pivot_table(traffic_Seoul_2019[['자치구명','발생건수','부상자수','사망자수']], \
                                    index='자치구명' , aggfunc=sum)
traffic_analysis.head()
# Out:
#       발생건수  부상자수  사망자수
# 자치구명
# 강남구   3722  5182    14
# 강동구   1414  1910    11
# 강북구   1277  1706     7
# 강서구   1829  2491    20
# 관악구   1363  1755    10

# %%
# 위도, 경도 데이터 불러오기
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xb0 in position 13: invalid start byte
# 윈도우에서 만든 데이터라서 에러 걸림 ->  encoding='euc-kr' 를 써야함.
seoul_limit = pd.read_csv("../Data/seoul.csv", encoding='euc-kr')
seoul_limit.columns = ['자치구명','lon','lat']
seoul_limit.head()
# Out:
#   자치구명       lon       lat
# 0  강남구  127.0475  37.51731
# 1  강동구  127.1238  37.53013
# 2  강북구  127.0255  37.63975
# 3  관악구  126.9515  37.47834
# 4  구로구  126.8875  37.49547

# %%
# traffic_Seoul_2019 와 seoul_limit의 병합
data_result =  pd.merge(traffic_analysis, seoul_limit, on='자치구명')
data_result.head()
# Out:
#   자치구명  발생건수  부상자수  사망자수       lon       lat
# 0  강남구  3722  5182    14  127.0475  37.51731
# 1  강동구  1414  1910    11  127.1238  37.53013
# 2  강북구  1277  1706     7  127.0255  37.63975
# 3  강서구  1829  2491    20  126.8496  37.55094
# 4  관악구  1363  1755    10  126.9515  37.47834

# %%
data_result.tail()
# Out:
#    자치구명  발생건수  부상자수  사망자수       lon       lat
# 20  용산구  1187  1614    10  126.9904  37.53254
# 21  은평구  1119  1464     7  126.9292  37.60278
# 22  종로구  1133  1559     6  126.9793  37.57323
# 23   중구  1184  1615     5  127.0032  37.55273
# 24  중랑구  1620  2122    12  127.0928  37.60652

# %%
data_result.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 25 entries, 0 to 24
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   자치구명    25 non-null     object
#  1   발생건수    25 non-null     int64
#  2   부상자수    25 non-null     int64
#  3   사망자수    25 non-null     int64
#  4   lon     25 non-null     float64
#  5   lat     25 non-null     float64
# dtypes: float64(2), int64(3), object(1)
# memory usage: 1.4+ KB

# %%
# folium을 사용하기 위해 int를 float로 변환해야 한다.
data_result[['발생건수','부상자수','사망자수']]=data_result[['발생건수','부상자수','사망자수']].astype(float)
data_result.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 25 entries, 0 to 24
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   자치구명    25 non-null     object
#  1   발생건수    25 non-null     float64
#  2   부상자수    25 non-null     float64
#  3   사망자수    25 non-null     float64
#  4   lon     25 non-null     float64
#  5   lat     25 non-null     float64
# dtypes: float64(5), object(1)
# memory usage: 1.4+ KB

# %% [markdown]
# ### 자치구의 구청을 표시하기

# %%
import folium

# %%
map = folium.Map(
    location=[37.5520, 126.982],
    zoom_start=11,
)

# 위치 정보를 Marker로 표시
for n in data_result.index:
    folium.Marker([data_result['lat'][n], data_result['lon'][n]],
    popup=data_result['자치구명'][n]).add_to(map)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_aa42b40f90fe409b46ea99399aa08f09 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_aa42b40f90fe409b46ea99399aa08f09&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_aa42b40f90fe409b46ea99399aa08f09 = L.map(
#                 &quot;map_aa42b40f90fe409b46ea99399aa08f09&quot;,
#                 {
#                     center: [37.552, 126.982],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_35e0ac89bdc22ed9ee0426fe38ae3041 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_aa42b40f90fe409b46ea99399aa08f09);
#
#
#             var marker_bb2eac524019cabe8fcd5a320f96f1a2 = L.marker(
#                 [37.51731, 127.0475],
#                 {}
#             ).addTo(map_aa42b40f90fe409b46ea99399aa08f09);
#
#
#         var popup_8ec79d43ca21dc64b1bff7a92cefd9d4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_6ced75b66cdc3002770a0684ae55c9d9 = $(`&lt;div id=&quot;html_6ced75b66cdc3002770a0684ae55c9d9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;강남구&lt;/div&gt;`)[0];
#             popup_8ec79d43ca21dc64b1bff7a92cefd9d4.setContent(html_6ced75b66cdc3002770a0684ae55c9d9);
#
#
#         marker_bb2eac524019cabe8fcd5a320f96f1a2.bindPopup(popup_8ec79d43ca21dc64b1bff7a92cefd9d4)
#         ;
#
#
#
#
#             var marker_5fd62a83749533011e538615e4d242ad = L.marker(
#                 [37.53013, 127.1238],
#                 {}
#             ).addTo(map_aa42b40f90fe409b46ea99399aa08f09);
#
#
#         var popup_0016c4f61edfcd6d830156399b7759fe = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_6a4043afe29e51c386b0ac71ab24ba57 = $(`&lt;div id=&quot;html_6a4043afe29e51c386b0ac71ab24ba57&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;강동구&lt;/div&gt;`)[0];
#             popup_0016c4f61edfcd6d830156399b7759fe.setContent(html_6a4043afe29e51c386b0ac71ab24ba57);
#
#
#         marker_5fd62a83749533011e538615e4d242ad.bindPopup(popup_0016c4f61edfcd6d830156399b7759fe)
#         ;
#
#
#
#
#             var marker_16183c3fee6f6b6a4028165919cdc9aa = L.marker(
#                 [37.63975, 127.0255],
#                 {}
#             ).addTo(map_aa42b40f90fe409b46ea99399aa08f09);
#
#
#         var popup_155107d08f6f1f087b8b230c4bfb10bd = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_86911a98f29b8ae8b9ed4080a662a396 = $(`&lt;div id=&quot;html_86911a98f29b8ae8b9ed4080a662a396&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;강북구&lt;/div&gt;`)[0];
#             popup_155107d08f6f1f087b8b230c4bfb10bd.setContent(html_86911a98f29b8ae8b9ed4080a662a396);
#
#
#         marker_16183c3fee6f6b6a4028165919cdc9aa.bindPopup(popup_155107d08f6f1f087b8b230c4bfb10bd)
#         ;
#
#
#
#
#             var marker_41fb785b9c6ce10557145c3246225402 = L.marker(
#                 [37.55094, 126.8496],
#                 {}
#             ).addTo(map_aa42b40f90fe409b46ea99399aa08f09);
#
#
#         var popup_e48641bd7b951c3b74eae9fab425544e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_7055db8150c18af6156a51d87562e627 = $(`&lt;div id=&quot;html_7055db8150c18af6156a51d87562e627&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;강서구&lt;/div&gt;`)[0];
#             popup_e48641bd7b951c3b74eae9fab425544e.setContent(html_7055db8150c18af6156a51d87562e627);
#
#
#         marker_41fb785b9c6ce10557145c3246225402.bindPopup(popup_e48641bd7b951c3b74eae9fab425544e)
#         ;
#
#
#
#
#             var marker_9db0a9a63fccc1c88391793e80cbb8b2 = L.marker(
#                 [37.47834, 126.9515],
#                 {}
#             ).addTo(map_aa42b40f90fe409b46ea99399aa08f09);
#
#
#         var popup_ff7e70937bb1342e304b1e03430d28d7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_f3a17c720bcad3096008976b4ef9c593 = $(`&lt;div id=&quot;html_f3a17c720bcad3096008976b4ef9c593&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;관악구&lt;/div&gt;`)[0];
#             popup_ff7e70937bb1342e304b1e03430d28d7.setContent(html_f3a17c720bcad3096008976b4ef9c593);
#
#
#         marker_9db0a9a63fccc1c88391793e80cbb8b2.bindPopup(popup_ff7e70937bb1342e304b1e03430d28d7)
#         ;
#
#
#
#
#             var marker_7fdf7f3f8452dbd5dfd63148b745a4b2 = L.marker(
#                 [37.53862, 127.0824],
#                 {}
#             ).addTo(map_aa42b40f90fe409b46ea99399aa08f09);
#
#
#         var popup_f9fa6ee666880bb58c03d0e04859a7d0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_a4569e027291237b7626f3d72ce4740b = $(`&lt;div id=&quot;html_a4569e027291237b7626f3d72ce4740b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;광진구&lt;/div&g

# %%
map = folium.Map(
    location=[37.5520, 126.982],
    zoom_start=11,
)

# 위치 정보를 Marker로 표시
for n in data_result.index:
    folium.Marker([data_result['lat'][n], data_result['lon'][n]],
    popup=data_result['자치구명'][n]).add_to(map)
    

# 자치구별 교통사고 발생건수를 표시하기. (숫자 데이터)
for n in data_result.index:
    folium.CircleMarker(
                [data_result['lat'][n], data_result['lon'][n]],
                radius=data_result['발생건수'][n]/100,
                fill = True,
                fill_opacity=0.3,
                popup=data_result['발생건수'][n]).add_to(map)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d4b935bbcd5d32d99f5d83a70a496c04 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d4b935bbcd5d32d99f5d83a70a496c04&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_d4b935bbcd5d32d99f5d83a70a496c04 = L.map(
#                 &quot;map_d4b935bbcd5d32d99f5d83a70a496c04&quot;,
#                 {
#                     center: [37.552, 126.982],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f89de6d4112ac2dc223c354f02065c2f = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_d4b935bbcd5d32d99f5d83a70a496c04);
#
#
#             var marker_a5cd17e5e2cfecbe3df635eb27414003 = L.marker(
#                 [37.51731, 127.0475],
#                 {}
#             ).addTo(map_d4b935bbcd5d32d99f5d83a70a496c04);
#
#
#         var popup_a9b268222381fc2b2b19462991cf70e7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_d1574234f88be5d2df18ca0a153f2aa4 = $(`&lt;div id=&quot;html_d1574234f88be5d2df18ca0a153f2aa4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;강남구&lt;/div&gt;`)[0];
#             popup_a9b268222381fc2b2b19462991cf70e7.setContent(html_d1574234f88be5d2df18ca0a153f2aa4);
#
#
#         marker_a5cd17e5e2cfecbe3df635eb27414003.bindPopup(popup_a9b268222381fc2b2b19462991cf70e7)
#         ;
#
#
#
#
#             var marker_a13b5fdee63e51aa94d56d7e95f1761c = L.marker(
#                 [37.53013, 127.1238],
#                 {}
#             ).addTo(map_d4b935bbcd5d32d99f5d83a70a496c04);
#
#
#         var popup_c6c8bdc2dd0ca766783c875291f17076 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_f35626b4b40059d562de623a64b0c0c1 = $(`&lt;div id=&quot;html_f35626b4b40059d562de623a64b0c0c1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;강동구&lt;/div&gt;`)[0];
#             popup_c6c8bdc2dd0ca766783c875291f17076.setContent(html_f35626b4b40059d562de623a64b0c0c1);
#
#
#         marker_a13b5fdee63e51aa94d56d7e95f1761c.bindPopup(popup_c6c8bdc2dd0ca766783c875291f17076)
#         ;
#
#
#
#
#             var marker_30d0fafa9a705732a40830107b1fa2fd = L.marker(
#                 [37.63975, 127.0255],
#                 {}
#             ).addTo(map_d4b935bbcd5d32d99f5d83a70a496c04);
#
#
#         var popup_94d0c02d2b73325082b47767659692a2 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_d0d6f5e3bb2be10db326581afee2a105 = $(`&lt;div id=&quot;html_d0d6f5e3bb2be10db326581afee2a105&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;강북구&lt;/div&gt;`)[0];
#             popup_94d0c02d2b73325082b47767659692a2.setContent(html_d0d6f5e3bb2be10db326581afee2a105);
#
#
#         marker_30d0fafa9a705732a40830107b1fa2fd.bindPopup(popup_94d0c02d2b73325082b47767659692a2)
#         ;
#
#
#
#
#             var marker_8cfb7682d400c57a2612151ce77ab239 = L.marker(
#                 [37.55094, 126.8496],
#                 {}
#             ).addTo(map_d4b935bbcd5d32d99f5d83a70a496c04);
#
#
#         var popup_782385975eb0d9b24ed3b3065b2622ee = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_ac30180b98faa1880fdebe3a33ddbf77 = $(`&lt;div id=&quot;html_ac30180b98faa1880fdebe3a33ddbf77&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;강서구&lt;/div&gt;`)[0];
#             popup_782385975eb0d9b24ed3b3065b2622ee.setContent(html_ac30180b98faa1880fdebe3a33ddbf77);
#
#
#         marker_8cfb7682d400c57a2612151ce77ab239.bindPopup(popup_782385975eb0d9b24ed3b3065b2622ee)
#         ;
#
#
#
#
#             var marker_18734210bf92ff9a2fd1558a851f857d = L.marker(
#                 [37.47834, 126.9515],
#                 {}
#             ).addTo(map_d4b935bbcd5d32d99f5d83a70a496c04);
#
#
#         var popup_3b4dc651db193631c4c420b8b15d4448 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_c8ab0dea71266fee1dfa2947a4588cac = $(`&lt;div id=&quot;html_c8ab0dea71266fee1dfa2947a4588cac&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;관악구&lt;/div&gt;`)[0];
#             popup_3b4dc651db193631c4c420b8b15d4448.setContent(html_c8ab0dea71266fee1dfa2947a4588cac);
#
#
#         marker_18734210bf92ff9a2fd1558a851f857d.bindPopup(popup_3b4dc651db193631c4c420b8b15d4448)
#         ;
#
#
#
#
#             var marker_34f1a12299f09691658ff35511b9cf8d = L.marker(
#                 [37.53862, 127.0824],
#                 {}
#             ).addTo(map_d4b935bbcd5d32d99f5d83a70a496c04);
#
#
#         var popup_726850a3ab830da6d5df3dbc74dd2af0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_ae01339a4ab205b52be7e30790e77db5 = $(`&lt;div id=&quot;html_ae01339a4ab205b52be7e30790e77db5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;광진구&lt;/div&g

# %%
# 자치구별 교통사고 사망건수 표시하기
map = folium.Map(
    location=[37.5520, 126.982],
    zoom_start=11,
)

# 위치 정보를 Marker로 표시
for n in data_result.index:
    folium.Marker([data_result['lat'][n], data_result['lon'][n]],
    popup=data_result['자치구명'][n]).add_to(map)
    

# 자치구별 교통사고 사망자수를 표시하기. (숫자 데이터)
for n in data_result.index:
    folium.CircleMarker(
                [data_result['lat'][n], data_result['lon'][n]],
                radius=data_result['사망자수'][n] * 2,
                fill = True,
                fill_opacity=0.3,
                color = 'firebrick',
                popup=data_result['사망자수'][n]).add_to(map)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ec3cd7c89882c491a9ae3db891234a1b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ec3cd7c89882c491a9ae3db891234a1b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_ec3cd7c89882c491a9ae3db891234a1b = L.map(
#                 &quot;map_ec3cd7c89882c491a9ae3db891234a1b&quot;,
#                 {
#                     center: [37.552, 126.982],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_91d20bd6e73a5e421197c8bff49b65f9 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_ec3cd7c89882c491a9ae3db891234a1b);
#
#
#             var marker_4bcc8481a78b400d8d0d52c53c24a5f5 = L.marker(
#                 [37.51731, 127.0475],
#                 {}
#             ).addTo(map_ec3cd7c89882c491a9ae3db891234a1b);
#
#
#         var popup_5b9602750be294c90deb546dfef78663 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_f0cfe6ded734ade305bac3c6d3444c04 = $(`&lt;div id=&quot;html_f0cfe6ded734ade305bac3c6d3444c04&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;강남구&lt;/div&gt;`)[0];
#             popup_5b9602750be294c90deb546dfef78663.setContent(html_f0cfe6ded734ade305bac3c6d3444c04);
#
#
#         marker_4bcc8481a78b400d8d0d52c53c24a5f5.bindPopup(popup_5b9602750be294c90deb546dfef78663)
#         ;
#
#
#
#
#             var marker_54d76c0a32e06e9553ef9be5c15f0f9b = L.marker(
#                 [37.53013, 127.1238],
#                 {}
#             ).addTo(map_ec3cd7c89882c491a9ae3db891234a1b);
#
#
#         var popup_7731b2b04b1825dcd45875d17ce968c0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_1d417176079b4a589396eefac6ae608a = $(`&lt;div id=&quot;html_1d417176079b4a589396eefac6ae608a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;강동구&lt;/div&gt;`)[0];
#             popup_7731b2b04b1825dcd45875d17ce968c0.setContent(html_1d417176079b4a589396eefac6ae608a);
#
#
#         marker_54d76c0a32e06e9553ef9be5c15f0f9b.bindPopup(popup_7731b2b04b1825dcd45875d17ce968c0)
#         ;
#
#
#
#
#             var marker_1b81516d56ce464745bb1dc651cfee82 = L.marker(
#                 [37.63975, 127.0255],
#                 {}
#             ).addTo(map_ec3cd7c89882c491a9ae3db891234a1b);
#
#
#         var popup_d09c4f58e6274679b90f95d86b1faf6a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_5b91fce0c4930f890f13c5120bc7cc53 = $(`&lt;div id=&quot;html_5b91fce0c4930f890f13c5120bc7cc53&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;강북구&lt;/div&gt;`)[0];
#             popup_d09c4f58e6274679b90f95d86b1faf6a.setContent(html_5b91fce0c4930f890f13c5120bc7cc53);
#
#
#         marker_1b81516d56ce464745bb1dc651cfee82.bindPopup(popup_d09c4f58e6274679b90f95d86b1faf6a)
#         ;
#
#
#
#
#             var marker_99dbf083f34cd146a2faf6628c4d0642 = L.marker(
#                 [37.55094, 126.8496],
#                 {}
#             ).addTo(map_ec3cd7c89882c491a9ae3db891234a1b);
#
#
#         var popup_358d500fc5329a5590e5387fd46e8925 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_7708c8b46d52b5b5da684c3eae98a824 = $(`&lt;div id=&quot;html_7708c8b46d52b5b5da684c3eae98a824&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;강서구&lt;/div&gt;`)[0];
#             popup_358d500fc5329a5590e5387fd46e8925.setContent(html_7708c8b46d52b5b5da684c3eae98a824);
#
#
#         marker_99dbf083f34cd146a2faf6628c4d0642.bindPopup(popup_358d500fc5329a5590e5387fd46e8925)
#         ;
#
#
#
#
#             var marker_af916e1a78e3c859cae13e837d6d89c6 = L.marker(
#                 [37.47834, 126.9515],
#                 {}
#             ).addTo(map_ec3cd7c89882c491a9ae3db891234a1b);
#
#
#         var popup_e76e63f1bb8b9bbf5a48e8e2cd225fc0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_36bf0b996986bf096e80d258dfd53af8 = $(`&lt;div id=&quot;html_36bf0b996986bf096e80d258dfd53af8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;관악구&lt;/div&gt;`)[0];
#             popup_e76e63f1bb8b9bbf5a48e8e2cd225fc0.setContent(html_36bf0b996986bf096e80d258dfd53af8);
#
#
#         marker_af916e1a78e3c859cae13e837d6d89c6.bindPopup(popup_e76e63f1bb8b9bbf5a48e8e2cd225fc0)
#         ;
#
#
#
#
#             var marker_dd7ec1ba5780aad523897af4162b5a87 = L.marker(
#                 [37.53862, 127.0824],
#                 {}
#             ).addTo(map_ec3cd7c89882c491a9ae3db891234a1b);
#
#
#         var popup_fcd180b18cc4e0342edbee0a16b8bc8a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_d4ee1e2ec3a940ee5938799366f5a63e = $(`&lt;div id=&quot;html_d4ee1e2ec3a940ee5938799366f5a63e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;광진구&lt;/div&g

# %%
# 사망자수 정렬후 index 재설정
data_result2 = data_result.sort_values(by='사망자수', ascending=False)
data_result2.reset_index(drop=True, inplace=True)
data_result2.tail()
# Out:
#    자치구명    발생건수    부상자수  사망자수       lon       lat
# 20  종로구  1133.0  1559.0   6.0  126.9793  37.57323
# 21  동작구  1406.0  2021.0   5.0  126.9393  37.51243
# 22   중구  1184.0  1615.0   5.0  127.0032  37.55273
# 23  도봉구   852.0  1163.0   4.0  127.0478  37.66873
# 24  광진구   973.0  1316.0   3.0  127.0824  37.53862

# %%
# 자치구별 교통사고 사망건수 표시하기
map = folium.Map(
    location=[37.5520, 126.982],
    zoom_start=11,
)

# 위치 정보를 Marker로 표시
for n in data_result2.index:
    folium.Marker([data_result2['lat'][n], data_result2['lon'][n]],
    popup=data_result2['자치구명'][n]).add_to(map)
    

# 자치구별 교통사고 사망자수의 최대값과 최소값을 표시하기. (숫자 데이터)
folium.CircleMarker(
            [data_result2['lat'][0], data_result2['lon'][0]],
            radius=data_result2['사망자수'][0] * 2,
            fill = True,
            fill_opacity=0.3,
            color = 'firebrick',
            popup=data_result2['사망자수'][0]).add_to(map)
folium.CircleMarker(
            [data_result2['lat'][len(data_result2)-1], data_result2['lon'][len(data_result2)-1]],
            radius=data_result2['사망자수'][len(data_result2)-1] * 2,
            fill = True,
            fill_opacity=0.3,
            color = 'indigo',
            popup=data_result2['사망자수'][len(data_result2)-1]).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4e3e75404475929d5fce3e7f3fbdd90c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4e3e75404475929d5fce3e7f3fbdd90c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_4e3e75404475929d5fce3e7f3fbdd90c = L.map(
#                 &quot;map_4e3e75404475929d5fce3e7f3fbdd90c&quot;,
#                 {
#                     center: [37.552, 126.982],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8bfc389c1d313e728e3a8cd826803bc3 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_4e3e75404475929d5fce3e7f3fbdd90c);
#
#
#             var marker_34a3c2285d8825e8024d67e16532a291 = L.marker(
#                 [37.55094, 126.8496],
#                 {}
#             ).addTo(map_4e3e75404475929d5fce3e7f3fbdd90c);
#
#
#         var popup_59fc887a64f1edf63fb10f5bfb4caf97 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_870464a8d2149cb3e4861fe7ec1190bc = $(`&lt;div id=&quot;html_870464a8d2149cb3e4861fe7ec1190bc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;강서구&lt;/div&gt;`)[0];
#             popup_59fc887a64f1edf63fb10f5bfb4caf97.setContent(html_870464a8d2149cb3e4861fe7ec1190bc);
#
#
#         marker_34a3c2285d8825e8024d67e16532a291.bindPopup(popup_59fc887a64f1edf63fb10f5bfb4caf97)
#         ;
#
#
#
#
#             var marker_da3a5c1e5e9d7ebe11de99561d466eaa = L.marker(
#                 [37.57452, 127.0396],
#                 {}
#             ).addTo(map_4e3e75404475929d5fce3e7f3fbdd90c);
#
#
#         var popup_a7535ac58b4cfdd6e0179b229f51d5f1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_a946b84386a791456e62e0de08a9febc = $(`&lt;div id=&quot;html_a946b84386a791456e62e0de08a9febc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;동대문구&lt;/div&gt;`)[0];
#             popup_a7535ac58b4cfdd6e0179b229f51d5f1.setContent(html_a946b84386a791456e62e0de08a9febc);
#
#
#         marker_da3a5c1e5e9d7ebe11de99561d466eaa.bindPopup(popup_a7535ac58b4cfdd6e0179b229f51d5f1)
#         ;
#
#
#
#
#             var marker_450e5e7ef31b1eb16634fe8bf9b28273 = L.marker(
#                 [37.51731, 127.0475],
#                 {}
#             ).addTo(map_4e3e75404475929d5fce3e7f3fbdd90c);
#
#
#         var popup_92d81624dc33151df40967228aafce43 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_eca41ec3fc0e81a2ac345300fa914682 = $(`&lt;div id=&quot;html_eca41ec3fc0e81a2ac345300fa914682&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;강남구&lt;/div&gt;`)[0];
#             popup_92d81624dc33151df40967228aafce43.setContent(html_eca41ec3fc0e81a2ac345300fa914682);
#
#
#         marker_450e5e7ef31b1eb16634fe8bf9b28273.bindPopup(popup_92d81624dc33151df40967228aafce43)
#         ;
#
#
#
#
#             var marker_329af08d89e1c3e90e06defd8b96691f = L.marker(
#                 [37.484, 127.033],
#                 {}
#             ).addTo(map_4e3e75404475929d5fce3e7f3fbdd90c);
#
#
#         var popup_917b7a07573b57d8708592cca3f70475 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_ffd515fcba6a1ee4581f9ed79d2e164f = $(`&lt;div id=&quot;html_ffd515fcba6a1ee4581f9ed79d2e164f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;서초구&lt;/div&gt;`)[0];
#             popup_917b7a07573b57d8708592cca3f70475.setContent(html_ffd515fcba6a1ee4581f9ed79d2e164f);
#
#
#         marker_329af08d89e1c3e90e06defd8b96691f.bindPopup(popup_917b7a07573b57d8708592cca3f70475)
#         ;
#
#
#
#
#             var marker_ed34ea9f7ddc8ecafedf0975652d7da9 = L.marker(
#                 [37.57908, 126.9368],
#                 {}
#             ).addTo(map_4e3e75404475929d5fce3e7f3fbdd90c);
#
#
#         var popup_5c5dd30501878d774743de7f4de25a83 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_b3e1a2ffe8bdc162a87bd1dc9b214cc7 = $(`&lt;div id=&quot;html_b3e1a2ffe8bdc162a87bd1dc9b214cc7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;서대문구&lt;/div&gt;`)[0];
#             popup_5c5dd30501878d774743de7f4de25a83.setContent(html_b3e1a2ffe8bdc162a87bd1dc9b214cc7);
#
#
#         marker_ed34ea9f7ddc8ecafedf0975652d7da9.bindPopup(popup_5c5dd30501878d774743de7f4de25a83)
#         ;
#
#
#
#
#             var marker_e21e7443212edaf734d654903189a161 = L.marker(
#                 [37.51448, 127.1059],
#                 {}
#             ).addTo(map_4e3e75404475929d5fce3e7f3fbdd90c);
#
#
#         var popup_e5fc07cf8560230b173c7d640094801c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_550f9250acc580fcdd1cdb10cdaceccf = $(`&lt;div id=&quot;html_550f9250acc580fcdd1cdb10cdaceccf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;송파구&lt;/div&gt

# %%
# 위에(치구별 교통사고 사망자수의 최대값과 최소값을 표시하기)랑 같은 그래프 그리기 다른버전

map = folium.Map(
    location=[37.5502, 126.982],
    zoom_start=11
)
for name, lat, lon, dead in zip(data_result.자치구명, data_result.lat, data_result.lon, data_result.사망자수):

    folium.Marker([lat,lon], popup=name).add_to(map)

# 자치구별 교통사고 사망자수의 최대값과 최소값을 표시하기. (숫자 데이터)
folium.CircleMarker(
                        [data_result.loc[data_result.사망자수 == data_result.사망자수.max(), "lat"],
                         data_result.loc[data_result.사망자수 == data_result.사망자수.max(), "lon"]],
                        radius = data_result.사망자수.max() * 1.9,
                        color = 'purple',
                        fill_color= 'purple',
                        fill_opacity= 0.7,
                        popup=name).add_to(map)

folium.CircleMarker(
                        [data_result.loc[data_result.사망자수 == data_result.사망자수.min(), "lat"],
                         data_result.loc[data_result.사망자수 == data_result.사망자수.min(), "lon"]],
                        radius = data_result.사망자수.min() * 1.9,
                        color = 'purple',
                        fill_color= 'purple',
                        fill_opacity= 0.7,
                        popup=name).add_to(map)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9a6af9e2ecca0251eabd7735d26ab882 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9a6af9e2ecca0251eabd7735d26ab882&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_9a6af9e2ecca0251eabd7735d26ab882 = L.map(
#                 &quot;map_9a6af9e2ecca0251eabd7735d26ab882&quot;,
#                 {
#                     center: [37.5502, 126.982],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9dbd2a638b4016347993d485618507c3 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_9a6af9e2ecca0251eabd7735d26ab882);
#
#
#             var marker_4312daefc46df0581921857dddd7470b = L.marker(
#                 [37.51731, 127.0475],
#                 {}
#             ).addTo(map_9a6af9e2ecca0251eabd7735d26ab882);
#
#
#         var popup_c5332a297e035662e8b62f617144bdf9 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_9d3f6039834e3fc9891c927f8c0dd6b5 = $(`&lt;div id=&quot;html_9d3f6039834e3fc9891c927f8c0dd6b5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;강남구&lt;/div&gt;`)[0];
#             popup_c5332a297e035662e8b62f617144bdf9.setContent(html_9d3f6039834e3fc9891c927f8c0dd6b5);
#
#
#         marker_4312daefc46df0581921857dddd7470b.bindPopup(popup_c5332a297e035662e8b62f617144bdf9)
#         ;
#
#
#
#
#             var marker_b52707879243733088af89256626ba5e = L.marker(
#                 [37.53013, 127.1238],
#                 {}
#             ).addTo(map_9a6af9e2ecca0251eabd7735d26ab882);
#
#
#         var popup_02e987d0f127367a03921744964f1042 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_9dc1a47a03ca83b182e5b8ffb21169e9 = $(`&lt;div id=&quot;html_9dc1a47a03ca83b182e5b8ffb21169e9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;강동구&lt;/div&gt;`)[0];
#             popup_02e987d0f127367a03921744964f1042.setContent(html_9dc1a47a03ca83b182e5b8ffb21169e9);
#
#
#         marker_b52707879243733088af89256626ba5e.bindPopup(popup_02e987d0f127367a03921744964f1042)
#         ;
#
#
#
#
#             var marker_05fa1179113924a6d18a4881f55603b0 = L.marker(
#                 [37.63975, 127.0255],
#                 {}
#             ).addTo(map_9a6af9e2ecca0251eabd7735d26ab882);
#
#
#         var popup_de328cc8c886a4af32d8a0707caa828c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_24f5fe12adad486b5e98f347f8335b0b = $(`&lt;div id=&quot;html_24f5fe12adad486b5e98f347f8335b0b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;강북구&lt;/div&gt;`)[0];
#             popup_de328cc8c886a4af32d8a0707caa828c.setContent(html_24f5fe12adad486b5e98f347f8335b0b);
#
#
#         marker_05fa1179113924a6d18a4881f55603b0.bindPopup(popup_de328cc8c886a4af32d8a0707caa828c)
#         ;
#
#
#
#
#             var marker_d219fe1471a1edc6aed5e8232e4b440a = L.marker(
#                 [37.55094, 126.8496],
#                 {}
#             ).addTo(map_9a6af9e2ecca0251eabd7735d26ab882);
#
#
#         var popup_0765f6385c80ab86ef700b6966d8152c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_08d1f328803632284f48a580f14d4b59 = $(`&lt;div id=&quot;html_08d1f328803632284f48a580f14d4b59&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;강서구&lt;/div&gt;`)[0];
#             popup_0765f6385c80ab86ef700b6966d8152c.setContent(html_08d1f328803632284f48a580f14d4b59);
#
#
#         marker_d219fe1471a1edc6aed5e8232e4b440a.bindPopup(popup_0765f6385c80ab86ef700b6966d8152c)
#         ;
#
#
#
#
#             var marker_669b9017233354797085e00d4761db1c = L.marker(
#                 [37.47834, 126.9515],
#                 {}
#             ).addTo(map_9a6af9e2ecca0251eabd7735d26ab882);
#
#
#         var popup_94b82c85b331394645c949a4c08daad2 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_3f4f75258fdc7e14f930b14eb810ffe2 = $(`&lt;div id=&quot;html_3f4f75258fdc7e14f930b14eb810ffe2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;관악구&lt;/div&gt;`)[0];
#             popup_94b82c85b331394645c949a4c08daad2.setContent(html_3f4f75258fdc7e14f930b14eb810ffe2);
#
#
#         marker_669b9017233354797085e00d4761db1c.bindPopup(popup_94b82c85b331394645c949a4c08daad2)
#         ;
#
#
#
#
#             var marker_31a051bc1ca5eb79aa2494bb0fbbecf4 = L.marker(
#                 [37.53862, 127.0824],
#                 {}
#             ).addTo(map_9a6af9e2ecca0251eabd7735d26ab882);
#
#
#         var popup_105d62266a4a6e930da7d7885ece6050 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_06ead1a9eda4e29a7129d6d233a5b87f = $(`&lt;div id=&quot;html_06ead1a9eda4e29a7129d6d233a5b87f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;광진구&lt;/div&
